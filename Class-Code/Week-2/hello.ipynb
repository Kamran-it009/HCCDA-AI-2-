# %%
n =  20
print('The type of n:', type(n))
f = float(n)
print('The type of f:', type(f))
h = 24
string = str(h)
print('The type of string:', type(string))
# Out:
# The type of n: <class 'int'>
# The type of f: <class 'float'>
# The type of string: <class 'str'>

# %%
int('A')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 int('A')
#
# ValueError: invalid literal for int() with base 10: 'A'

# %%
bin(10)
# Out:
# '0b1010'

# %%
int('0b1010', 2)
# Out:
# 10

# %%
bool(13)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool('C') # any string
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
bool(23.5)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
name = input()
print('Your name is:', name)
# Out:
# Your name is: Kamran

# %%
name = input('Enter your name:')
print('Your name is:', name)
# Out:
# Your name is: Kamran

# %%
age = int(input('Enter your age:'))
print('your age is:', age)
print(type(age))
# Out:
# your age is: 12
# <class 'int'>

# %% [markdown]
# ### Strings

# %%
name = 'Muhammad Kamran Khan'
print(name)
# Out:
# Muhammad Kamran Khan

# %%
name[9]
# Out:
# 'K'

# %%
name[-2]
# Out:
# 'a'

# %%
name[9: 15]
# Out:
# 'Kamran'

# %%
name[9: 15: 2]
# Out:
# 'Kma'

# %%
name[3:]
# Out:
# 'ammad Kamran Khan'

# %%
name[: 9]
# Out:
# 'Muhammad '

# %%
name[:]
# Out:
# 'Muhammad Kamran Khan'

# %%
name[-6: -9]
# Out:
# ''

# %%
name[-9: -6]
# Out:
# 'mra'

# %%
name[9: -2]
# Out:
# 'Kamran Kh'

# %%
name = 'Kamran'
age = 25
print("My name is {} and I am {} years old.".format(name, age))
# Out:
# My name is Kamran and I am 25 years old.

# %%
print("The is Doctor's advice")
# Out:
# The is Doctor's advice

# %%
print('The is Doctor\'s advice')
# Out:
# The is Doctor's advice

# %%
# string Comparision
str1 = "apple"
str2 = "almond"
is_equal = str1 == str2  
print("Checking strings are equal or not:", is_equal)
# Out:
# Checking strings are equal or not: False

# %%
# string Comparision
str1 = "apple"
str2 = "apple"
is_equal = str1 == str2  
print("Checking strings are equal or not:", is_equal)
# Out:
# Checking strings are equal or not: True

# %%
str1 = "apple"
str2 = "Apple"
is_equal = str1 == str2  
print("Checking strings are equal or not:", is_equal)
# Out:
# Checking strings are equal or not: False

# %%
str1 = "banana"
str2 = "Apple"
str1 > str2
# Out:
# True

# %%
str1 = '3456' # 51
str2 = "apple" # 90
str1 > str2
# Out:
# False

# %%
str1 < str2
# Out:
# True

# %%
fruits = ['apple', 'banana', 'cherry', 'mango', 'orange', 'almond', 'melon']
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'orange', 'almond', 'melon']

# %%
ages = [20, 30, 40, 50]
ages
# Out:
# [20, 30, 40, 50]

# %%
mixed_data = ['apple', 34, 35.6, True]
mixed_data
# Out:
# ['apple', 34, 35.6, True]

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'orange', 'almond', 'melon']

# %%
fruits[2] = 'grapes'

# %%
fruits
# Out:
# ['apple', 'banana', 'grapes', 'mango', 'orange', 'almond', 'melon']

# %%
# immutable
name = 'Kamran'
name.extend('Khan')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 3
#       1 # immutable
#       2 name = 'Kamran'
# ----> 3 name.extend('Khan')
#
# AttributeError: 'str' object has no attribute 'extend'

# %%
#Second Update
fruits[2: 5] = ['cherry', 'stawberry', 'Guava']
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'stawberry', 'Guava', 'almond', 'melon']

# %%
fruits.insert(1, 'grapes')
print(fruits)
# Out:
# ['apple', 'grapes', 'banana', 'cherry', 'stawberry', 'Guava', 'almond', 'melon']

# %%
fruits.append('watermelon')

# %%
fruits
# Out:
# ['apple',
#  'grapes',
#  'banana',
#  'cherry',
#  'stawberry',
#  'Guava',
#  'almond',
#  'melon',
#  'watermelon']

# %%
product1 = ['Mobile', 'telephone', 'airbods']
product2 = ['shirts', 'hoddies', 'jeans']

product1.extend(product2)
print(product1)
# Out:
# ['Mobile', 'telephone', 'airbods', 'shirts', 'hoddies', 'jeans']

# %%
# remove()
fruits.remove('melon')
print(fruits)
# Out:
# ['apple', 'grapes', 'banana', 'cherry', 'stawberry', 'Guava', 'almond', 'watermelon']

# %%
fruits2 = ['apple', 'grapes', 'banana', 'cherry', 'stawberry', 'melon', 'melon', 'watermelon']

# %%
fruits2.remove('melon')

# %%
fruits2
# Out:
# ['apple', 'grapes', 'banana', 'cherry', 'stawberry', 'melon', 'watermelon']

# %%
trash = fruits2.pop(-2)

# %%
trash
# Out:
# 'melon'

# %%
fruits2
# Out:
# ['apple', 'grapes', 'banana', 'cherry', 'stawberry', 'watermelon']

# %%
fruits2.append(trash)

# %%
fruits2
# Out:
# ['apple', 'grapes', 'banana', 'cherry', 'stawberry', 'watermelon', 'melon']

# %%
name
# Out:
# 'Kamran'

# %%
# Upper Case
print('String in uppercase:', name.upper())
# Out:
# String in uppercase: KAMRAN

# %%
fruits = ['guava', 'Strawbery', 'almond', 'apple', 'grapes']
fruits
# Out:
# ['guava', 'Strawbery', 'almond', 'apple', 'grapes']

# %%
# Case no: 1- sorting 
fruits.sort()
print(fruits)
# Out:
# ['Strawbery', 'almond', 'apple', 'grapes', 'guava']

# %%
fruits3 = ['Stawberry', 'Cherry', 'Apple', 'apple', 'grapes', 'mango']

# %%
fruits3
# Out:
# ['Stawberry', 'Cherry', 'Apple', 'apple', 'grapes', 'mango']

# %%
fruits3.sort()
fruits3
# Out:
# ['Apple', 'Cherry', 'Stawberry', 'apple', 'grapes', 'mango']

# %%
fruits3
# Out:
# ['Apple', 'Cherry', 'Stawberry', 'apple', 'grapes', 'mango']

# %%
numbers = [23, 34, 64, 21, 12]
numbers
# Out:
# [23, 34, 64, 21, 12]

# %%
numbers.sort(reverse=True)

# %%
numbers
# Out:
# [64, 34, 23, 21, 12]

# %%
fruits3 = ['stawberry', 'cherry', 'apple', 'grapes', 'mango', 'melon']
fruits4 = ['stawberry', 'cherry', 'apple', 'grapes', 'mango']

# %%
fruits3
# Out:
# ['stawberry', 'cherry', 'apple', 'grapes', 'mango', 'melon']

# %%
fruits3.sort(reverse=True)
print('Desceding Sort: ', fruits3)
fruits4.reverse()
print(fruits4)
# Out:
# Desceding Sort:  ['stawberry', 'melon', 'mango', 'grapes', 'cherry', 'apple']
# ['mango', 'grapes', 'apple', 'cherry', 'stawberry']

# %%
x = 10
y = x
print(id(x))
print(id(y))
# membership operator
print(x is y)
# Out:
# 140735948318104
# 140735948318104
# True

# %%
x = -10
y = x
y = y + 2
print(id(x))
print(id(y))
# membership operator
print(x is y)
# Out:
# 2259480915728
# 2259482015824
# False

# %%
fruits
# Out:
# ['Strawbery', 'almond', 'apple', 'grapes', 'guava']

# %%
original = fruits
print('original: ', original)
print('fruits:', fruits)
# Out:
# original:  ['Strawbery', 'almond', 'apple', 'grapes', 'guava']
# fruits: ['Strawbery', 'almond', 'apple', 'grapes', 'guava']

# %%
fruits.append('melon')

# %%
print('original: ', original)
print('fruits:', fruits)
# Out:
# original:  ['Strawbery', 'almond', 'apple', 'grapes', 'guava', 'melon']
# fruits: ['Strawbery', 'almond', 'apple', 'grapes', 'guava', 'melon']

# %%
original is fruits
# Out:
# True

# %%
original = fruits.copy()
print(original is fruits)
# Out:
# False

# %%
fruits.append('watermlon')
print('original: ', original)
print('fruits:', fruits)
# Out:
# original:  ['Strawbery', 'almond', 'apple', 'grapes', 'guava', 'melon']
# fruits: ['Strawbery', 'almond', 'apple', 'grapes', 'guava', 'melon', 'watermlon']

# %%
# 2D List
fruits_veg = [['apple', 'banana', 'cherry'], ['Brinjal', 'Potato', 'Radish']]
print(fruits_veg)
# Out:
# [['apple', 'banana', 'cherry'], ['Brinjal', 'Potato', 'Radish']]

# %%
two_d_list = ['apple', 'banana', 'cherry', ['melon', 'mango'], 'grapes']
two_d_list
# Out:
# ['apple', 'banana', 'cherry', ['melon', 'mango'], 'grapes']

# %%
print(fruits_veg[0])
print(fruits_veg[0][-1], ':', fruits_veg[1])
print(fruits_veg[0][-1][3])
print(fruits_veg[0][-1][5])
# Out:
# ['apple', 'banana', 'cherry']
# cherry : ['Brinjal', 'Potato', 'Radish']
# r
# y

# %%
print(fruits_veg[0][-1][3][3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 print(fruits_veg[0][-1][3][3])
#
# IndexError: string index out of range

# %%
fruits_veg = [[['apple', 'banana', 'cherry']],
               [['Brinjal', 'Potato', 'Radish']]]

# %%
print(fruits_veg[0])
print(fruits_veg[1][0])
print(fruits_veg[1][0][2])
print(fruits_veg[1][0][2][3])
# Out:
# [['apple', 'banana', 'cherry']]
# ['Brinjal', 'Potato', 'Radish']
# Radish
# i

# %%
# Creating Tuples
vegetables = ('Potato', 'Spinish', 'Carrot', 'Onion', 'Garlic', 'Cabbage')
print(vegetables)
# Out:
# ('Potato', 'Spinish', 'Carrot', 'Onion', 'Garlic', 'Cabbage')

# %%
vegetables[-1]
# Out:
# 'Cabbage'

# %%
vegetables[2]
# Out:
# 'Carrot'

# %%
vegetables[2:]
# Out:
# ('Carrot', 'Onion', 'Garlic', 'Cabbage')

# %%
vegetables.index('Onion')
# Out:
# 3

# %%
vegetables = ('Potato', 'Spinish', 'Carrot', 'Onion', 'Garlic', 'Cabbage')

# %%
veg_list = list(vegetables)
print(veg_list)
# Out:
# ['Potato', 'Spinish', 'Carrot', 'Onion', 'Garlic', 'Cabbage']

# %%
veg_list.append('Cauli-Flower')

# %%
vegetables = tuple(veg_list)

# %%
vegetables
# Out:
# ('Potato', 'Spinish', 'Carrot', 'Onion', 'Garlic', 'Cabbage', 'Cauli-Flower')

# %% [markdown]
# ### Dictionary

# %%
fruits_dict = {'A': 'apple', 'B': 'banana', 'C': 'cherry'}
fruits_dict2 = {10: 'apple', 20: 'banana', 30: 'cherry'}

# %%
fruits_dict['B']
# Out:
# 'banana'

# %%
fruits_dict[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 fruits_dict[-1]
#
# KeyError: -1

# %%
fruits_dict['A': 'C']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 fruits_dict['A': 'C']
#
# KeyError: slice('A', 'C', None)

# %%
fruits_dict['A'] = ['almond', 'apple']
print(fruits_dict)
# Out:
# {'A': ['almond', 'apple'], 'B': 'banana', 'C': 'cherry'}

# %%
fruits_dict['A'][-1]
# Out:
# 'apple'

# %%
sequence = ('apple', 'banana', 'cherry')
new_dict = dict.fromkeys(sequence, 0)

# %%
new_dict
# Out:
# {'apple': 0, 'banana': 0, 'cherry': 0}

# %%
fruits_dict['A']
# Out:
# ['almond', 'apple']

# %%
fruits_dict.get('A')
# Out:
# ['almond', 'apple']

# %%
fruits_dict['D']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 fruits_dict['D']
#
# KeyError: 'D'

# %%
fruits_dict.get('D')

# %%
fruits_dict.items()
# Out:
# dict_items([('A', ['almond', 'apple']), ('B', 'banana'), ('C', 'cherry')])

# %%
type(fruits_dict.items())
# Out:
# dict_items

# %%
fruits_dict.keys()
# Out:
# dict_keys(['A', 'B', 'C'])

# %%
fruits_dict.values()
# Out:
# dict_values([['almond', 'apple'], 'banana', 'cherry'])

# %%
fruits_dict.popitem()
# Out:
# ('C', 'cherry')

# %%
fruits_dict
# Out:
# {'A': ['almond', 'apple'], 'B': 'banana'}

# %%
# Set Creation
fruits = {'apple', 'banana', 'cherry', 'orange', 'melon', 'watermelon'}
print(fruits)
# Out:
# {'orange', 'melon', 'cherry', 'banana', 'apple', 'watermelon'}

# %%
fruits[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 fruits[0]
#
# TypeError: 'set' object is not subscriptable

# %%
fruits = {'apple', 'banana', 'orange', 'melon', 'watermelon'}
print(fruits)
# Out:
# {'orange', 'melon', 'banana', 'apple', 'watermelon'}
